# %% [markdown]
# <a href="https://colab.research.google.com/github/vijayshreesunshine-ux/data-science-masters/blob/main/pandas3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df.iloc[2:6]
# Out:
#    PassengerId  Survived  Pclass  \
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
# 5                              Moran, Mr. James    male   NaN      0      0
#
#              Ticket     Fare Cabin Embarked
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S
# 5            330877   8.4583   NaN        Q

# %%
df['Name'][2:6]

# %%
list(df['Name'])

# %%
l=['a','b','c']
pd.Series(l)

# %%
pd.Series(list(df['Name'][2:7]),index=['a','b','c','d','e'])

# %%
s=pd.Series(df['Name'][2:7],index=['a','b','c','d','e'])

# %%
s1=df['Name'][2:10]

# %%
s2= s1+s

# %%
s2 = pd.concat([s2, s1])

# %%
s2

# %%
s2*2

# %%
df.drop("PassengerId",axis=1)

# %%
df

# %%
df.drop("PassengerId",axis=1,inplace=True)

# %%
df

# %%
df.drop(3)

# %%
df.drop(3 , implace=True)

# %%
  df.set_index("Name",inplace=True)

# %%
df

# %%
df.loc['Heikkinem,Miss.Laina']

# %%
df.iloc[2]

# %%
df.head()

# %%
df.reset_index()

# %%
df.head()

# %%
df.reset_index(inplace=True)

# %%
d={'key1':[1,2,3,4],
    'key2':[3,4,5,6],
   'key3':[5,6,7,8]}

# %%
pd.DataFrame(d)

# %%
df1=pd.read_csv("taxonomy.csv.xls")

# %%
df1

# %%
df1.dropna()

# %%
df1.dropna(axis=1)

# %%
df1.fillna("vijayshree")

# %%
df.head()

# %%
df.groupby('Survived').mean(numeric_only=True)
# Out:
#           PassengerId    Pclass        Age     SibSp     Parch       Fare
# Survived
# 0          447.016393  2.531876  30.626179  0.553734  0.329690  22.117887
# 1          444.368421  1.950292  28.343690  0.473684  0.464912  48.395408

# %%
df.groupby('Survived').sum()
# Out:
#           PassengerId  Pclass  \
# Survived
# 0              245412    1390
# 1              151974     667
#
#                                                        Name  \
# Survived
# 0         Braund, Mr. Owen HarrisAllen, Mr. William Henr...
# 1         Cumings, Mrs. John Bradley (Florence Briggs Th...
#
#                                                         Sex       Age  SibSp  \
# Survived
# 0         malemalemalemalemalemalemalefemalemalefemalema...  12985.50    304
# 1         femalefemalefemalefemalefemalefemalefemalefema...   8219.67    162
#
#           Parch                                             Ticket  \
# Survived
# 0           181  A/5 2117137345033087717463349909A/5. 215134708...
# 1           159  PC 17599STON/O2. 3101282113803347742237736PP 9...
#
#                 Fare                                              Cabin  \
# Survived
# 0         12142.7199  E46C23 C25 C27B30C83F G73E31A5D26C110B58 B60D2...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.groupby("Sex").sum(numeric_only=True)['Fare']
# Out:
# Sex
# female    13966.6628
# male      14727.2865
# Name: Fare, dtype: float64

# %%
from os import nice
df.groupby("Sex").mean(numeric_only=True)['Age']
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
df3=df.groupby("Pclass").sum(numeric_only=True)

# %%
df3.T
# Out:
# Pclass                1           2            3
# PassengerId  99705.0000  82056.0000  215625.0000
# Survived       136.0000     87.0000     119.0000
# Age           7111.4200   5168.8300    8924.9200
# SibSp           90.0000     74.0000     302.0000
# Parch           77.0000     70.0000     193.0000
# Fare         18177.4125   3801.8417    6714.6951

# %%
df3.transpose()
# Out:
# Pclass                1           2            3
# PassengerId  99705.0000  82056.0000  215625.0000
# Survived       136.0000     87.0000     119.0000
# Age           7111.4200   5168.8300    8924.9200
# SibSp           90.0000     74.0000     302.0000
# Parch           77.0000     70.0000     193.0000
# Fare         18177.4125   3801.8417    6714.6951

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df11=df[['Name','Survived','Pclass']][0:5]

# %%
df12=df[['Name','Survived','Pclass']][5:10]

# %%
df11
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                           Allen, Mr. William Henry         0       3

# %%
df12
# Out:
#                                                 Name  Survived  Pclass
# 5                                   Moran, Mr. James         0       3
# 6                            McCarthy, Mr. Timothy J         0       1
# 7                     Palsson, Master. Gosta Leonard         0       3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 9                Nasser, Mrs. Nicholas (Adele Achem)         1       2

# %%
pd.concat([df11,df12])
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                           Allen, Mr. William Henry         0       3
# 5                                   Moran, Mr. James         0       3
# 6                            McCarthy, Mr. Timothy J         0       1
# 7                     Palsson, Master. Gosta Leonard         0       3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 9                Nasser, Mrs. Nicholas (Adele Achem)         1       2

# %%
df5=pd.concat([df11,df12],axis=1)

# %%
df5=df5.fillna("vijayshree")

# %%
df5
# Out:
#                                                 Name    Survived      Pclass  \
# 0                            Braund, Mr. Owen Harris         0.0         3.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1.0         1.0
# 2                             Heikkinen, Miss. Laina         1.0         3.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1.0         1.0
# 4                           Allen, Mr. William Henry         0.0         3.0
# 5                                         vijayshree  vijayshree  vijayshree
# 6                                         vijayshree  vijayshree  vijayshree
# 7                                         vijayshree  vijayshree  vijayshree
# 8                                         vijayshree  vijayshree  vijayshree
# 9                                         vijayshree  vijayshree  vijayshree
#
#                                                 Name    Survived      Pclass
# ...

# %%
data1=pd.DataFrame({'key1':[1,2,3,4],
    'key2':[3,4,5,6],
   'key3':[5,6,7,8]})

# %%
data2=pd.DataFrame({'key1':[1,2,3,4],
    'key2':[6,4,5,6],
   'key3':[5,6,7,8]})

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     3     5
# 1     2     4     6
# 2     3     5     7
# 3     4     6     8

# %%
data2
# Out:
#    key1  key2  key3
# 0     1     6     5
# 1     2     4     6
# 2     3     5     7
# 3     4     6     8

# %%
pd.merge(data1,data2)
# Out:
#    key1  key2  key3
# 0     2     4     6
# 1     3     5     7
# 2     4     6     8

# %%
pd.merge(data1,data2,how='left')
# Out:
#    key1  key2  key3
# 0     1     3     5
# 1     2     4     6
# 2     3     5     7
# 3     4     6     8

# %%
pd.merge(data1,data2,how='right')
# Out:
#    key1  key2  key3
# 0     1     6     5
# 1     2     4     6
# 2     3     5     7
# 3     4     6     8

# %%
pd.merge(data2,data1,how='left')
# Out:
#    key1  key2  key3
# 0     1     6     5
# 1     2     4     6
# 2     3     5     7
# 3     4     6     8

# %%
pd.merge(data1,data2,how='outer')
# Out:
#    key1  key2  key3
# 0     1     3     5
# 1     1     6     5
# 2     2     4     6
# 3     3     5     7
# 4     4     6     8

# %%
pd.merge(data1,data2,how='cross')
# Out:
#     key1_x  key2_x  key3_x  key1_y  key2_y  key3_y
# 0        1       3       5       1       6       5
# 1        1       3       5       2       4       6
# 2        1       3       5       3       5       7
# 3        1       3       5       4       6       8
# 4        2       4       6       1       6       5
# 5        2       4       6       2       4       6
# 6        2       4       6       3       5       7
# 7        2       4       6       4       6       8
# 8        3       5       7       1       6       5
# 9        3       5       7       2       4       6
# 10       3       5       7       3       5       7
# 11       3       5       7       4       6       8
# 12       4       6       8       1       6       5
# 13       4       6       8       2       4       6
# 14       4       6       8       3       5       7
# 15       4       6       8       4       6       8

# %%
pd.merge(data1,data2,how='left',left_on='key2',right_on='key1')
# Out:
#    key1_x  key2_x  key3_x  key1_y  key2_y  key3_y
# 0       1       3       5     3.0     5.0     7.0
# 1       2       4       6     4.0     6.0     8.0
# 2       3       5       7     NaN     NaN     NaN
# 3       4       6       8     NaN     NaN     NaN

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     3     5
# 1     2     4     6
# 2     3     5     7
# 3     4     6     8

# %%
data2
# Out:
#    key1  key2  key3
# 0     1     6     5
# 1     2     4     6
# 2     3     5     7
# 3     4     6     8

# %%
data3=pd.DataFrame({'key1':[1,2,3,4],
    'key2':[3,4,5,6],
   'key3':[5,6,7,8]},index=['a','b','c','d'])

# %%
data4=pd.DataFrame({'key11':[1,2,3,4],
    'key22':[6,4,5,6],
   'key33':[5,6,7,8]},index=['a','b','j','i'])

# %%
data3.join(data4)
# Out:
#    key1  key2  key3  key11  key22  key33
# a     1     3     5    1.0    6.0    5.0
# b     2     4     6    2.0    4.0    6.0
# c     3     5     7    NaN    NaN    NaN
# d     4     6     8    NaN    NaN    NaN

# %%
df['fare_inr']=df['Fare'].apply(lambda x:x*80)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  fare_inr
# 0      0         A/5 21171   7.2500   NaN        S   580.000
# 1      0          PC 17599  71.2833   C85        C  5702.664
# 2      0  STON/O2. 3101282   7.9250   NaN        S   634.000
# 3      0            113803  53.1000  C123        S  4248.000
# ...

# %%
df['name_length']=df['Name'].apply(len)

# %%
 df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  fare_inr  name_length
# 0      0         A/5 21171   7.2500   NaN        S   580.000           23
# 1      0          PC 17599  71.2833   C85        C  5702.664           51
# 2      0  STON/O2. 3101282   7.9250   NaN        S   634.000           22
# ...

# %%
def inr_con(x):
  return x*80
df['fare_inr']=df['Fare'].apply(inr_con)

# %%
def create_flaf(x):
  if x<10:
    return "cheap"
  elif x>=10 and x<20:
      return "normal"
  else:
      return "expensive"

# %%
df['Flag_fare']=df['Fare'].apply(create_flaf)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  fare_inr  name_length  \
# 0      0         A/5 21171   7.2500   NaN        S   580.000           23
# 1      0          PC 17599  71.2833   C85        C  5702.664           51
# 2      0  STON/O2. 3101282   7.9250   NaN        S   634.000           22
# ...
